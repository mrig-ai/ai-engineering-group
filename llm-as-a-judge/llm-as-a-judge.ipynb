# %% [markdown]
# ### LLM as a Judge
#
# This notebook demonstrates using a large language model (LLM) to **evaluate responses** or make judgments on specific questions.
#
# We will:
#
# - Format a prompt with examples and a target question.
# - Send it to the LLM for evaluation.
# - Collect the critique and outcome in a structured way.

# %% [markdown]
# ### Setup
#
# This cell installs and imports all the necessary libraries, loads environment variables, and sets up the API key for using the Google GenAI client.
#
# - **pandas**: For data manipulation.
# - **os & dotenv**: To load environment variables securely.
# - **pydantic**: To define structured output schemas.
# - **google.genai**: To interact with the Google LLM API.
# - **yaml**: Optional, for reading or writing YAML configurations.
#
# We also load the `GOOGLE_API_KEY` from a `.env` file to authenticate requests to the LLM.

# %%
import pandas as pd 
import os 
from pydantic import BaseModel, Field 
from google import genai 
from google.genai import types 
from dotenv import load_dotenv 
import yaml 

load_dotenv() 

GOOGLE_API_KEY= os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ### Define Output Schema
#
# We define a **Pydantic model** to structure the LLM's output:
#
# - `critique`: A detailed explanation of the LLM's reasoning.
# - `outcome`: The final judgment based on the critique (e.g., "pass" or "fail").
#
# Using a schema ensures the model's responses are **consistent and machine-readable**.

# %%
class LLMValidatorOutput(BaseModel): 
    critique: str = Field( description="The formulated detailed critique explaining your reasoning") 
    outcome: str = Field(description="The outcome of the critique (pass/fail)")

# %% [markdown]
# ### Load Prompt Template
#
# Here we load the **prompt template** from a YAML file (`prompt.yml`).

# %%
prompt = yaml.safe_load(open("prompt.yml", "r")) 
prompt_template = prompt['template']['content']

# %% [markdown]
# ### Format Examples for Prompt
#
# This function converts a DataFrame of examples into a **structured text format** that the LLM can understand.
#
# - Each example includes:
#   - `<nlq>`: The user question.
#   - `<response>`: The AI's answer.
#   - `<evaluation>`: A JSON-like critique and outcome.
# - The function wraps each example in `<example-{i}>` tags for clarity.
#
# This makes it easy to feed multiple examples into the prompt in a consistent format.

# %%
def format_examples(df_examples: pd.DataFrame) -> str: 
    examples_list = [ 
        f""" <example-{i}> 
        <nlq>{example["User"].strip()}</nlq> 
        <response>{example["AI"].strip()}</response> 
        <evaluation> 
        {{ 
            "critique": "{example["Critique"].strip()}", 
            "outcome": "{example["Judgement"].strip().lower()}" 
            }} 
            </evaluation> 
            </example-{i}> """ 
            for i, example in df_examples.iterrows() 
            ] 
    return "\n".join(examples_list)

# %% [markdown]
# ### Initialize LLM Client
#
# We set up the **Google GenAI client** and define a configuration for generating content:
#
# - `temperature=0.0`: Ensures deterministic outputs for consistent evaluation.
# - `response_mime_type='application/json'`: Returns the output in JSON format.
# - `response_schema=LLMValidatorOutput`: Validates that the LLM's response follows our predefined schema (`critique` and `outcome`).

# %%
llm_instance = genai.Client(api_key=GOOGLE_API_KEY) 
config = types.GenerateContentConfig( 
    temperature=0.0, 
    response_mime_type='application/json', 
    response_schema=LLMValidatorOutput 
    )

# %% [markdown]
# ### Load Ground Truth Data
#
# We load the **ground truth dataset** containing example features, user questions, AI responses, critiques, and judgments
#
# This dataset will be used to:
#
# - Provide examples to the LLM.
# - Compare new AI responses against established evaluations.
# - Generate structured prompts for the LLM to critique and judge.

# %%
df_groundtruth = pd.read_csv("data/groundtruth-vs2.csv") 
df_groundtruth
# Out:
#    ID            Feature                      Scenario  \
# 0   1      Product order                Order Tracking
# 1   2      Product order              Delivery Options
# 2   3      Product order            Order cancellation
# 3   4      Product order                  Lost Package
# 4   5      Product order  Modify Order Before Shipment
# 5   6  Return Management       Initiate Product Return
# 6   7  Return Management                Request Refund
# 7   8  Return Management           Seller Non-Response
# 8   9    Payment Options             Access to invoice
# 9  11    Payment Options      Accepted Payment Methods
#
#                                                 User  \
# 0                                     Track an order
# 1      Hello, is it possible to schedule a delivery?
# 2           I would like to cancel my order, please.
# 3                     Lost package / missing parcel.
# 4  Hello, I would like to change the size of a pr...
# 5                           How to return a product.
# 6                            How can I get refunded?
# 7  You replied to me one week ago that the seller...
# 8                               Download an invoice.
# 9                 What payment methods are accepted?
#
#                                                   AI Judgement  \
# 0  For purchases made directly from our website, ...      PASS
# 1  For purchases made directly from our website, ...      FAIL
# 2  For purchases made directly from our website, ...      PASS
# 3  For purchases made directly from our website, ...      FAIL
# 4  For purchases made directly from our website, ...      FAIL
# 5  For purchases fromour website, you can return ...      PASS
# 6  For purchases made directly from our website, ...      PASS
# 7  For purchases from Marketplace sellers, you mu...      FAIL
# 8  To download your invoice, first log in to your...      PASS
# 9  For purchases on our website, the following pa...      PASS
#
#                                             Critique
# 0  The AI's response comprehensively covers how t...
# 1  The user's question is clear and straightforwa...
# 2  Critique:\nThe user’s question, "I want to can...
# 3  Critique:\nThe user’s query, "lost parcel," in...
# 4  Critique:\nThe user’s question is clear: they ...
# 5  Critique:\nThe user’s question, "How to return...
# 6  Critique:\nThe user’s question, "How do I get ...
# 7  critique:\nThe user’s question indicates frust...
# 8  Critique:\nThe AI's response effectively instr...
# 9  Critique:\nIntroduction:\nThe user inquired ab...

# %% [markdown]
# ### Load Chatbot Answers
#
# We load the dataset containing **AI-generated answers** to various user questions.
#
# This dataset will be used to:
#
# - Feed questions and answers into the LLM for evaluation.
# - Compare the LLM's critique and judgment against ground truth examples.

# %%
df_qa = pd.read_csv("data/chatbot-answers-vs2.csv") 
df_qa
# Out:
#                   question                                         llm_answer  \
# 0           Track an order  For purchases made directly from our website, ...
# 1  How to return a product  For purchases made directly from our website, ...
# 2      Download an invoice  To download your invoice, follow these steps:\...
# 3          Cancel an order  For purchases made directly from our website, ...
# 4                   Refund  For purchases made directly from our website, ...
# 5   Can i use my visa card  I’m sorry, but Visa cards are not accepted for...
#
#              Feature
# 0      Product Order
# 1  Return Management
# 2    Payment Options
# 3      Product Order
# 4  Return Management
# 5    Payment Options

# %% [markdown]
# ### Select Test Case
#
# Here we select a **single test example** from the chatbot answers dataset to evaluate.
#
# This allows us to **focus on one case** while testing the LLM evaluation workflow.

# %%
df_test= df_qa.iloc[0:1].reset_index(drop=True) 
# df_test= df_qa.iloc[1:2].reset_index(drop=True) 
# df_test= df_qa.iloc[5:6].reset_index(drop=True) 
df_test
# Out:
#                  question                                         llm_answer  \
# 0  Can i use my visa card  I’m sorry, but Visa cards are not accepted for...
#
#            Feature
# 0  Payment Options

# %% [markdown]
# ### Generate Formatted Prompt
#
# This loop constructs the **final prompt** for each test case in `df_test`:
#
# - Retrieves relevant examples from the ground truth dataset that match the current feature.
# - Fills the prompt template with:
#   - Feature name
#   - Example blocks  (Few-shot Prompting)
#   - Test question and the AI's answer
#
# This step ensures the LLM receives a **well-structured, context-rich prompt** for evaluation.

# %%
import pprint 

for idx, row in df_test.iterrows(): 
    prompt_template = prompt_template 
    examples_text = format_examples(df_groundtruth[df_groundtruth["Feature"].str.lower() == row["Feature"].lower()]) 
    
    formatted_prompt_str = prompt_template.format( 
        feature=row.get("Feature", ""), 
        examples=examples_text, 
        question=row.get("question", ""), 
        llm_answer=row.get("llm_answer", "") ) 

formatted_prompt_str = formatted_prompt_str.strip() 
pprint.pp(formatted_prompt_str)
# Out:
# ('You are an AI response evaluator with advanced capabilities to judge if a '
#  'response is appropriate, helpful, and meets specific evaluation criteria. \n'
#  'Your role is to assess responses involving Payment Options-related queries, '
#  'guided by detailed evaluation standards.\n'
#  '\n'
#  '### Guidelines for Evaluation:\n'
#  'Consider the following criteria when evaluating the response:\n'
#  '\n'
#  '1. **Accuracy and Relevance**  \n'
#  "  - Does the response directly address the customer's query?  \n"
#  '  - Is the information factually accurate and aligned with official company '
#  'policies?  \n'
#  '\n'
#  '2. **Completeness**  \n'
#  "  - Does the response fully address all aspects of the customer's query?  \n"
#  '  - Are there any critical details, steps, or aspects of the query left '
#  'unaddressed?  \n'
#  '\n'
#  '3. **Clarity and Understandability**  \n'
#  '  - Is the response written in simple and clear language, avoiding '
#  'unnecessary jargon?  \n'
#  '  - Is it structured logically so the customer can easily follow and '
#  'understand the information?  \n'
#  '\n'
#  '4. **Adherence to Company Policies**  \n'
#  '  - Does the response align with official company policies, terms, and '
#  'procedures?  \n'
#  '  - Are there any parts of the response that include conflicting, '
#  'misleading, or incorrect information?  \n'
#  '\n'
#  '5. **Professional and Helpful Tone**  \n'
#  '  - Is the tone polite, empathetic, and professional throughout?  \n'
#  '  - Does the response convey a genuine willingness to assist the customer '
#  'effectively?  \n'
#  '\n'
#  '### Guidelines for Completing the Task:\n'
#  '1. **Reasoning Steps**:  \n'
#  '  - Offer a detailed critique that explains your reasoning based on the '
#  'criteria above.  \n'
#  '  - Reference specific examples provided (if relevant) and explain why the '
#  'response passes or fails each individual criterion.  \n'
#  '\n'
#  '2. **Judgment**:  \n'
#  '  - Conclude with a clear pass/fail judgment based on whether the response '
#  'sufficiently meets the evaluation criteria in totality.\n'
#  '\n'
#  '### Provided Examples:\n'
#  'You have access to evaluation examples wrapped in XML tags that demonstrate '
#  'how to critique and evaluate responses effectively. \n'
#  'Refer to these examples to ensure alignment with expectations.  \n'
#  '<examples> <example-8> \n'
#  '        <nlq>Download an invoice.</nlq> \n'
#  '        <response>To download your invoice, first log in to your customer '
#  'account.\n'
#  'Then go to https://move.app.link/order_tracing\n'
#  'and select the relevant order.\n'
#  'If your order was shipped more than 5 days ago, you’ll see the option '
#  '“Download my invoice”.\n'
#  'You can then save or print it.\n'
#  'If your order was shipped by a Marketplace seller, contact them through your '
#  'account using the “I have a question” button to obtain your '
#  'invoice.</response> \n'
#  '        <evaluation> \n'
#  '        { \n'
#  '            "critique": "Critique:\n'
#  "The AI's response effectively instructs the user on how to download an "
#  'invoice for both orders made directly through the website and those '
#  'processed through Marketplace sellers. The guidance provided is clear, '
#  'direct, and aligns well with the steps outlined in the website’s '
#  'documentation.\n'
#  '\n'
#  'Key Reasons for Passing:\n'
#  '\n'
#  'Accurate Instructions for Website Orders:\n'
#  'The AI response correctly details the steps for obtaining an invoice for '
#  'orders made directly from the website. This includes logging into the '
#  'account, navigating through the provided link, selecting the relevant order, '
#  'and downloading the invoice if the order has been shipped for more than 5 '
#  'days. These steps are consistent with the instructions specified in the '
#  'documentation.\n'
#  '\n'
#  'Clear Guidance for Marketplace Orders:\n'
#  'For orders made through Marketplace sellers, the AI appropriately advises '
#  'the user to contact the seller via the messaging system in their client '
#  'space to request the invoice. This guidance correctly reflects the procedure '
#  'for obtaining invoices from Marketplace sellers as indicated in the '
#  'documentation.\n'
#  '\n'
#  'Comprehensive Coverage:\n'
#  'The response covers all necessary aspects of the invoice retrieval process '
#  'for both types of orders (direct and Marketplace), ensuring that users '
#  'receive complete information relevant to their specific situation.\n'
#  '\n'
#  'Areas for Improvement:\n'
#  '\n'
#  'Direct Link Provision:\n'
#  'Although the AI mentions using a specific link to access the order tracking '
#  'page, it could enhance user convenience by embedding the link directly in '
#  'the response text, making it clickable and more accessible.\n'
#  '\n'
#  'Clarification on Invoice Availability:\n'
#  'The response mentions that the invoice option appears if the order has been '
#  'shipped for more than 5 days. It could further clarify that this condition '
#  'applies specifically to website orders and not necessarily to Marketplace '
#  'orders, where the process might vary depending on the seller.\n'
#  '\n'
#  'Details on Communication with Marketplace Sellers:\n'
#  'While the response directs users to contact the seller for invoices on '
#  'Marketplace orders, providing a brief explanation on how to use the “I have '
#  'a question” button could improve user understanding and ease of use.\n'
#  '\n'
#  'Conclusion:\n'
#  'The AI response successfully meets the user’s needs by providing detailed '
#  'instructions on how to download invoices for both website and Marketplace '
#  'orders. The information is accurate, actionable, and aligns with the '
#  'provided documentation. While there are areas where the response could be '
#  'slightly enhanced for clarity and user convenience, these do not detract '
#  'from the overall effectiveness of the answer. Thus, it passes.", \n'
#  '            "outcome": "pass" \n'
#  '            } \n'
#  '            </evaluation> \n'
#  '            </example-8> \n'
#  ' <example-9> \n'
#  '        <nlq>What payment methods are accepted?</nlq> \n'
#  '        <response>For purchases on our website, the following payment '
#  'methods are accepted:\n'
#  'Bank cards: Visa, Mastercard, American Express\n'
#  'PayPal: One-time payment or 4 interest-free installments\n'
#  'Apple Pay and Google Pay (depending on device compatibility)\n'
#  'Installment payment: 3 or 4 times without fees for purchases between €40 and '
#  '€4000\n'
#  'Checks are no longer accepted. Your data is secured through encrypted '
#  'servers.</response> \n'
#  '        <evaluation> \n'
#  '        { \n'
#  '            "critique": "Critique:\n'
#  'Introduction:\n'
#  'The user inquired about the payment methods accepted by the website. The AI '
#  'response lists the various payment options available, including credit '
#  'cards, and other methods, while providing some details about restrictions '
#  'and compatibility. The response largely aligns with the available '
#  'documentation and fulfills the user’s intent to understand the available '
#  'payment methods. However, there are minor areas where the response could be '
#  'improved for greater clarity and completeness.\n'
#  '\n'
#  'Key Reasons for Passing:\n'
#  '\n'
#  'Comprehensive Coverage of Payment Methods:\n'
#  'The AI response correctly includes the major payment methods accepted by the '
#  'website, such as credit cards (Visa, Mastercard, American Express), PayPal, '
#  'Apple Pay, Google Pay.\n'
#  '\n'
#  'Security Emphasis:\n'
#  'The AI highlights that payment data is secured using encryption, which is an '
#  'important reassurance for users.\n'
#  '\n'
#  'Alignment with Documentation:\n'
#  'The response aligns well with the detailed information provided in the '
#  'documentation about the various payment methods and their conditions.\n'
#  '\n'
#  'Structure and Readability:\n'
#  'The response could be better organized by grouping payment methods (e.g., '
#  'credit cards, digital wallets) under clear headings or bullet points for '
#  'improved readability.\n'
#  '\n'
#  'Suggestions for Improvement:\n'
#  '\n'
#  'Clearly group payment methods by type for better readability.\n'
#  '\n'
#  '\n'
#  'Conclusion:\n'
#  "The AI response effectively meets the user's intent by providing a "
#  'comprehensive overview of the payment methods accepted by the website, '
#  'including key restrictions and compatibility. While there are minor '
#  'opportunities for improving clarity, structure, and completeness, these do '
#  'not detract significantly from the overall adequacy of the answer. '
#  'Therefore, the response earns a pass.", \n'
#  '            "outcome": "pass" \n'
#  '            } \n'
#  '            </evaluation> \n'
#  '            </example-9> </examples>  \n'
#  '\n'
#  '### Evaluation Task:\n'
#  'For the following query and response wrapped in XML tags, evaluate the '
#  'response based on the above criteria:  \n'
#  '<query>Can i use my visa card</query>  \n'
#  '<response>I’m sorry, but Visa cards are not accepted for this service. '
#  'Please try another payment method, such as Mastercard, American Express, or '
#  'PayPal.</response>  \n'
#  '\n'
#  '### Notes:\n'
#  '- Be objective in your assessment, strictly adhering to the guidelines and '
#  'examples provided.  \n'
#  '- If a response fails to meet even one critical criterion (e.g., accuracy, '
#  'completeness, policy adherence), it may warrant a "fail" judgment unless '
#  'minor issues can reasonably be overlooked.')

# %% [markdown]
# ### Send Prompt to LLM
#
# Here we send the **formatted prompt** to the LLM for evaluation:
#
# - `model="gemini-2.0-flash"` specifies the LLM to use.
# - `contents=formatted_prompt_str` provides the structured input prompt.
# - `config=config` applies our generation settings, including:
#   - Deterministic output (`temperature=0.0`)
#   - JSON response format
#   - Schema validation (`LLMValidatorOutput`)
#
# The LLM will return a **critique and outcome** based on the provided examples and test case.

# %%
response = llm_instance.models.generate_content( 
    # model="gemini-2.0-flash-lite",
    model="gemini-2.0-flash", 
    contents=formatted_prompt_str, 
    config=config 
    )

# %% [markdown]
# ### Display LLM Outcome
#
# Here we extract the **final judgment** from the LLM's response:
#
# - `response.parsed.outcome` contains the verdict (e.g., `"pass"` or `"fail"`).
# - This shows the LLM's overall evaluation of the AI-generated answer based on the provided examples and prompt.

# %%
response.parsed.outcome
# Out:
# 'pass'

# %% [markdown]
# ### Display LLM Critique
#
# After sending the prompt, we extract and display the **detailed critique** from the LLM's response:
#
# - `response.parsed.critique` contains the reasoning behind the LLM's judgment.
#
# This helps us understand **why the LLM evaluated the answer as it did**.

# %%
pprint.pp(response.parsed.critique)
# Out:
# ("The response directly answers the user's question about using a Visa card. "
#  'It states that Visa cards are not accepted and suggests alternative payment '
#  "methods. The response is clear, concise, and directly addresses the user's "
#  'query. It adheres to a professional tone and provides helpful information by '
#  "suggesting alternatives. However, without knowing the specific service, it's "
#  'impossible to verify the accuracy of the statement about Visa card '
#  'acceptance. Assuming the information is accurate, the response is helpful '
#  "and meets the user's needs.")
